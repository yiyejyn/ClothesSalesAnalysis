# %%
#===================오민재===============================
from selenium import webdriver as wd
import cx_Oracle
import os
import time
import re
p = re.compile('만족')
p1 = re.compile("2019|2018")
p2 = re.compile("결제완료")
p3 = re.compile("일")
p4 = re.compile("건")
p5 = re.compile("조회수")
p6 = re.compile("장바구니")
os.putenv("NLS_LANG",".UTF8")
connection = cx_Oracle.connect('hr' , '1234' , 'localhost/xe')
cursor = connection.cursor()
#접속할 주소
url = "https://store.musinsa.com/app/items/lists/001005"
#자동으로 웹 동작을 할 수 있다
driver = wd.Chrome(executable_path="chromedriver.exe")
#사이트 로드를 10초동안 기다리고 10초 안에 로드 완료시 다음 라인 실행
driver.implicitly_wait(10)
#url에 접속 하겠따.
driver.get(url)
cloth_container = driver.find_element_by_class_name("list-box")
cloth_list = cloth_container.find_elements_by_class_name("li_box")
total_page = int(driver.find_element_by_class_name("is_goods").text.split(":")[-1].replace("개","").replace(",",""))
if(total_page % 80 == 0):
    total_page = total_page // 80
else:
    total_page = (total_page // 80) +1
for page in range(1,(total_page+1)):
    driver.execute_script("listSwitchPage(document.f1, '{}')".format(page))
    time.sleep(3)
    for i in range(0,80):
        try:
            cloth_container = driver.find_element_by_class_name("list-box")
            cloth_list = cloth_container.find_elements_by_class_name("li_box")
            cloth_list[i].find_element_by_class_name("img-block").click()
            print("brand: ",driver.find_element_by_css_selector(".product_article>li>.product_article_contents>strong>a"))

        except:
            time.sleep(3)
            driver.refresh()
            cloth_container = driver.find_element_by_class_name("list-box")
            cloth_list = cloth_container.find_elements_by_class_name("li_box")
            cloth_list[i].find_element_by_class_name("img-block").click()
            print("brand: ",driver.find_element_by_css_selector(".product_article>li>.product_article_contents>strong>a"))

#===================오민재===============================
#===================전현진===============================

        brand = driver.find_element_by_css_selector(".product_article>li>.product_article_contents>strong>a").text
        print("season: ",driver.find_element_by_class_name("product_article"))
        season_div = driver.find_element_by_class_name("product_info_section")
        season_Ul = season_div.find_element_by_class_name("product_article")
        season_li_list = season_Ul.find_elements_by_tag_name("li")
        season = ""
        total_sell = ""
        review = ""
        bucket = ""
        popularity = ""
        print(len(season_li_list))
        for index in range(0,len(season_li_list)):
            result = season_li_list[index].find_element_by_class_name("product_article_contents")
            season_test = result.text
            if p1.search(season_test) != None:
                if(season_test.split("/")[-1].replace(" ","") == "남"):
                    season = season_test.replace("남","").replace(" ","")
            if p2.search(season_test) != None:
                total_sell = int(season_test.split("개")[0].replace(",",""))
            if p5.search(season_test) != None:
                popularity = int(season_test.split("(조회수")[0].replace(",",""))
                bucket = int(season_test.split("(장바구니")[0].split("/")[1].replace(" ","").replace(",",""))

        sex_container = driver.find_element_by_class_name("txt_gender")
        sex = sex_container.find_element_by_tag_name("span").text


        title = driver.find_element_by_class_name("product_title").text

        like_ = ""
        try:
            like_ = int(driver.find_element_by_class_name("prd_like_cnt").text.replace(",",""))
        except:
            like_ = ""
        satisfaction = ""
        satisfaction_list = driver.find_elements_by_class_name("product_article_contents")
        for index in satisfaction_list:
            if p.search(index.text) != None:
                satisfaction = float(index.text.split("/")[1].split("%")[0].replace(" ",""))
                review = int(index.text.split("/")[0].split("건")[0].replace(",",""))
                break;
#===================전현진===============================
#===================이예진===============================

        img_url_div = driver.find_element_by_class_name("product-img")
        img_url = img_url_div.find_element_by_tag_name("img").get_attribute("src")

        delivery_date_container = driver.find_element_by_class_name("delivery_info_section")
        dLi_list = delivery_date_container.find_elements_by_tag_name("li")
        delivery_date = ""
        for index in range(0,len(dLi_list)):
            result = dLi_list[index].find_element_by_class_name("product_article_contents")
            test = result.text
            if(p3.search(test)) != None:
                delivery_date = float(test.split("일")[0])
        price_container = driver.find_element_by_class_name("price_info_section")
        pLi_list = price_container.find_elements_by_tag_name("li")
        price = ""
        sale = ""
        print(len(dLi_list))
        print(len(pLi_list))

        for li in pLi_list:
            print(li.text)
        try:
            if(len(pLi_list) == 6 or len(pLi_list) == 7):
                price = int(driver.find_element_by_id("sale_price").text.split("원")[0].replace(",",""))
                sale = float((driver.find_element_by_class_name("txt_kor_discount").text.split("%")[0]))

            else:
                price = driver.find_element_by_id("goods_price").text.replace("원","").replace(",","")
                sale = ""
        except:
            price = int(driver.find_element_by_id("goods_price").text.replace("원","").replace(",",""))
            sale = ""



        category_container = driver.find_element_by_class_name('item_categories')
        category_ = category_container.find_elements_by_tag_name("a")[1].text


        print("num: " , i)
        print("brand: " , brand)
        print("season: " , season)
        print("sex: " , sex)
        print("title: " , title)
        print("popularity: " , popularity)
        print("bucket: " , bucket)
        print("like_: " , like_)
        print("review: " , review)
        print("satisfaction: " , satisfaction)
        print("total_sell: " , total_sell)
        print("delivery_date: " , delivery_date)
        print("price",price)
        print("sale" , sale)
        print("category_",category_)
        print("img_url",img_url)
        print("="*130)
        
        driver.back()
        time.sleep(3)
#===================이예진===============================
# Out:
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.33548824770102326-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.33548824770102326-2")>
# 4
# 2
# 5
#
# -무신사 판매가 42,900 원
# -무신사 회원가 39,039 ~ 42,042 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 1,716원 (바로접속 ON, 로그인 필요)
# num:  0
# brand:  UNI APPAREL
# season:  2019F/W/
# sex:  남
# title:  베이직 기모 터틀넥 스웨트셔츠 카키|BASIC TUMBLE 950G TURTLENECK SWEAT SHIRTS KHAKI
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  1.7
# price 42900
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1249022/1249022_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.6993723837552825-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.6993723837552825-2")>
# 5
# 2
# 5
#
# -무신사 판매가 42,900 원
# -무신사 회원가 39,039 ~ 42,042 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 1,716원 (바로접속 ON, 로그인 필요)
# num:  1
# brand:  UNI APPAREL
# season:  2019F/W/
# sex:  남
# title:  베이직 기모 터틀넥 스웨트셔츠 인디고블루|BASIC TUMBLE 950G TURTLENECK SWEAT SHIRTS INDIGO BLUE
# popularity:
# bucket:
# like_:  2
# review:
# satisfaction:
# total_sell:
# delivery_date:  1.7
# price 42900
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1249029/1249029_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.4381703938780732-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.4381703938780732-2")>
# 5
# 2
# 6
#
# -무신사 판매가 85,800 원
# -무신사 세일가 68,800 원 20% (-17,000원) 할인
# -무신사 회원가 62,608 ~ 67,424 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,752원 (바로접속 ON, 로그인 필요)
# num:  2
# brand:  XCXMAIN
# season:  2019F/W/
# sex:  남
# title:  [세트상품]프리미엄 스웨트셔츠 NO.1 SET (6RODUCT)|[세트상품]프리미엄 스웨트셔츠 NO.1 SET (6RODUCT)
# popularity:
# bucket:
# like_:  14
# review:
# satisfaction:
# total_sell:
# delivery_date:  2.4
# price 68800
# sale 20.0
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248726/1248726_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.13874019664208737-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.13874019664208737-2")>
# 5
# 2
# 6
#
# -무신사 판매가 85,800 원
# -무신사 세일가 68,800 원 20% (-17,000원) 할인
# -무신사 회원가 62,608 ~ 67,424 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,752원 (바로접속 ON, 로그인 필요)
# num:  3
# brand:  XCXMAIN
# season:  2019F/W/
# sex:  남
# title:  [세트상품]프리미엄 스웨트셔츠 NO.2 SET (6RODUCT)|[세트상품]프리미엄 스웨트셔츠 NO.2 SET (6RODUCT)
# popularity:
# bucket:
# like_:  14
# review:
# satisfaction:
# total_sell:
# delivery_date:  2.4
# price 68800
# sale 20.0
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248727/1248727_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.23015583575333332-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.23015583575333332-2")>
# 4
# 2
# 5
#
# -무신사 판매가 54,000 원
# -무신사 회원가 49,140 ~ 52,920 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,160원 (바로접속 ON, 로그인 필요)
# num:  4
# brand:  SIGNAP
# season:  2019F/W/
# sex:  남
# title:  CiTY newyork ogfull design oversize sweatshirts gray|CiTY newyork ogfull design oversize sweatshirts gray
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  1.7
# price 54000
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248950/1248950_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.29492446103724945-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.29492446103724945-2")>
# 4
# 2
# 6
#
# -무신사 판매가 79,000 원
# -무신사 세일가 67,150 원 15% (-11,850원) 할인
# -무신사 회원가 61,106 ~ 65,807 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,686원 (바로접속 ON, 로그인 필요)
# num:  5
# brand:  OUTX.O
# season:
# sex:  여
# title:  zipup mtm-purple|zipup mtm-purple
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  10.4
# price 67150
# sale 15.0
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191203/1241660/1241660_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.0050666983663647525-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.0050666983663647525-2")>
# 4
# 2
# 6
#
# -무신사 판매가 79,000 원
# -무신사 세일가 67,150 원 15% (-11,850원) 할인
# -무신사 회원가 61,106 ~ 65,807 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,686원 (바로접속 ON, 로그인 필요)
# num:  6
# brand:  OUTX.O
# season:
# sex:  여
# title:  zipup mtm-ivory|zipup mtm-ivory
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  10.4
# price 67150
# sale 15.0
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191203/1241661/1241661_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.7130060133636811-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.7130060133636811-2")>
# 5
# 2
# 5
#
# -무신사 판매가 54,000 원
# -무신사 회원가 49,140 ~ 52,920 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,160원 (바로접속 ON, 로그인 필요)
# num:  7
# brand:  SIGNAP
# season:
# sex:  여
# title:  CiTY paris ogfull design oversize sweatshirts lavender|CiTY paris ogfull design oversize sweatshirts lavender
# popularity:
# bucket:
# like_:  1
# review:
# satisfaction:
# total_sell:
# delivery_date:  1.7
# price 54000
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248952/1248952_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.2126893946229511-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.2126893946229511-2")>
# 4
# 2
# 5
#
# -무신사 판매가 19,900 원
# -무신사 회원가 18,109 ~ 19,502 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 796원 (바로접속 ON, 로그인 필요)
# num:  8
# brand:  TOPTEN
# season:
# sex:  여
# title:  여성) 라이트 플리스 맨투맨_MSA1TR2001LYE|여성) 라이트 플리스 맨투맨_MSA1TR2001LYE
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  3.4
# price 19900
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191206/1246072/1246072_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.6995119427502907-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.6995119427502907-2")>
# 4
# 2
# 5
#
# -무신사 판매가 148,000 원
# -무신사 회원가 134,680 ~ 145,040 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 5,920원 (바로접속 ON, 로그인 필요)
# num:  9
# brand:  STIGMA
# season:  2019F/W/
# sex:  남
# title:  CREAM OVERSIZED WOOL TURTLE NECK SWEATER IVORY|CREAM OVERSIZED WOOL TURTLE NECK SWEATER IVORY
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  1.5
# price 148000
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248914/1248914_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.19639871638264483-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.19639871638264483-2")>
# 5
# 2
# 5
#
# -무신사 판매가 128,000 원
# -무신사 회원가 116,480 ~ 125,440 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 5,120원 (바로접속 ON, 로그인 필요)
# num:  10
# brand:  STIGMA
# season:  2019F/W/
# sex:  남
# title:  PYRAMID OVERSIZED WOOL SWEATER BLACK|PYRAMID OVERSIZED WOOL SWEATER BLACK
# popularity:
# bucket:
# like_:  1
# review:
# satisfaction:
# total_sell:
# delivery_date:  1.5
# price 128000
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248912/1248912_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.8997114023310107-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.8997114023310107-2")>
# 5
# 2
# 5
#
# -무신사 판매가 69,000 원
# -무신사 회원가 62,790 ~ 67,620 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,760원 (바로접속 ON, 로그인 필요)
# num:  11
# brand:  NINEOCTOPUS
# season:  2019F/W/
# sex:  남
# title:  소녀 자수 스웨트셔츠|girl sweat shirt
# popularity:
# bucket:
# like_:  1
# review:
# satisfaction:
# total_sell:
# delivery_date:  1.5
# price 69000
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248798/1248798_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.3080495957883693-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.3080495957883693-2")>
# 5
# 2
# 3
#
# -무신사 판매가 368,000 원
# -무신사 적립금 최대 14,720원 (바로접속 ON, 로그인 필요)
# num:  12
# brand:  BAPE
# season:
# sex:  남
# title:  CITY CAMO WGM SHARK L/S TEE|CITY CAMO WGM SHARK L/S TEE
# popularity:
# bucket:
# like_:  1
# review:
# satisfaction:
# total_sell:
# delivery_date:  3.5
# price 368000
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248706/1248706_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.9012228360983598-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.9012228360983598-2")>
# 4
# 2
# 3
#
# -무신사 판매가 468,000 원
# -무신사 적립금 최대 18,720원 (바로접속 ON, 로그인 필요)
# num:  13
# brand:  BAPE
# season:
# sex:  남
# title:  TIGER HEAVY WEIGHT CREWNECK|TIGER HEAVY WEIGHT CREWNECK
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  3.5
# price 468000
# sale
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248725/1248725_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.6420061124119174-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.6420061124119174-2")>
# 5
# 2
# 6
#
# -무신사 판매가 69,000 원
# -무신사 세일가 55,200 원 20% (-13,800원) 할인
# -무신사 회원가 50,232 ~ 54,096 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,208원 (바로접속 ON, 로그인 필요)
# num:  14
# brand:  ALLAND
# season:  2019F/W/
# sex:  남
# title:  보아 머플러 맨투맨 티셔츠 LMTRI4M01-102|보아 머플러 맨투맨 티셔츠 LMTRI4M01-102
# popularity:
# bucket:
# like_:  1
# review:
# satisfaction:
# total_sell:
# delivery_date:  2.6
# price 55200
# sale 20.0
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248614/1248614_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.9956281027264839-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.9956281027264839-2")>
# 5
# 2
# 6
#
# -무신사 판매가 69,000 원
# -무신사 세일가 55,200 원 20% (-13,800원) 할인
# -무신사 회원가 50,232 ~ 54,096 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,208원 (바로접속 ON, 로그인 필요)
# num:  15
# brand:  ALLAND
# season:  2019F/W/
# sex:  남
# title:  보아 머플러 맨투맨 티셔츠 LMTRI4M01-190|보아 머플러 맨투맨 티셔츠 LMTRI4M01-190
# popularity:
# bucket:
# like_:  1
# review:
# satisfaction:
# total_sell:
# delivery_date:  2.6
# price 55200
# sale 20.0
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248617/1248617_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.5540513225255803-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.5540513225255803-2")>
# 4
# 2
# 6
#
# -무신사 판매가 69,000 원
# -무신사 세일가 55,200 원 20% (-13,800원) 할인
# -무신사 회원가 50,232 ~ 54,096 원 ▼
# ㄴ 바로접속 ON 시 무신사 회원가가 적용됩니다.
# ㄴ 쿠폰 사용이 허용된 상품입니다. [보유 쿠폰을 확인] 하세요.
#
# -무신사 적립금 최대 2,208원 (바로접속 ON, 로그인 필요)
# num:  16
# brand:  ALLAND
# season:  2019F/W/
# sex:  남
# title:  보아 머플러 맨투맨 티셔츠 LMTRI4M01-509|보아 머플러 맨투맨 티셔츠 LMTRI4M01-509
# popularity:
# bucket:
# like_:
# review:
# satisfaction:
# total_sell:
# delivery_date:  2.6
# price 55200
# sale 20.0
# category_ 맨투맨/스웨트셔츠
# img_url https://image.msscdn.net/images/goods_img/20191211/1248616/1248616_1_500.jpg
# ==================================================================================================================================
# brand:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.7968717862299028-1")>
# season:  <selenium.webdriver.remote.webelement.WebElement (session="77b5bbbf5cac97b4712d75b8cfd33e42", element="0.7968717862299028-2")>
# 4
