# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
pf = pd.read_csv("musinsa_final.csv")
#title컬럼을 기준으로 중복 값 제거 
pf = pf.drop_duplicates(['TITLE'])
pf = pf.sort_values(['TOTAL_SELL'], ascending = False)
pf.head(80)
# Out:
#       index                                              TITLE  \
# 7         7     [세트] 하프 폴라 니트 티셔츠|[SET] Half Pola Knit T-Shirt
# 265     265  레거시91 테크 스우시캡 블랙 / 892651-010|레거시91 테크 스우시캡 블랙...
# 149     149  캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우|CAMP VARSITY PIGMENT ...
# 1309   1309  (2PACK) 챔피온 T425 무지 반팔티|(2PACK) CHAMPION T425 ...
# 72       72  12/20 배송 1931 OBJECT JEANS [CROP STRAIGHT]|193...
# 46       46  올드스쿨 - 블랙 / VN000D3HY281|VN-0D3HY28 / OLD SKOO...
# 1029   1029     [세트상품] 더블 코튼 롱 티셔츠|Double Cotton Long T-Shirts
# 4228   4228        3일 지연 피치스킨 트윌 자켓 블랙|Peach Skin Twill Jacket
# 668     668  Layla endless love Fluff Mood Check shirt S24 ...
# 248     248  클래식 슬립온 - (Checkerboard) 블랙:화이트 / VN000EYEBWW1...
# 322     322  3-스트라이프 트레이닝 팬츠 - 블랙 / CM1409|3-Stripe trainin...
# 761     761  12/13 배송 [FW ver.](유니섹스) 와이드 밴딩 슬랙스_Black|[FW ...
# 1195   1195  (마지막한정수량 재입고) Wooltan Check Shirts (Cream)|(마지...
# 191     191  12/20 배송 LOCATION LOGO CREWNECK IA [INDIGO BLU...
# ...

# %%
pf.head()
#널 값을 알아본다
#모든 null값을 0으로 치환한다.
pf = pf.drop(['TITLE', 'BRAND' , 'SEASON' , 'SEX' , 'BUCKET' , 'IMG_URL' , 'LIKE_' , 'REVIEW' , 'CATEGORY_'] , axis=1)
np.sum(pd.isnull(pf))
# Out:
# index                0
# POPULARITY           1
# TOTAL_SELL       35635
# SATISFACTION         1
# DELIVERY_DATE      394
# PRICE                1
# SALE             19699
# dtype: int64

# %%
#Y값의 null이 많기 때문에 null 값을 0으로 바꿔준다
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'].isnull() ,0 , pf['TOTAL_SELL'])
pf['POPULARITY'] = np.where(pf['POPULARITY'].isnull() ,0 , pf['POPULARITY'])
pf['SALE'] = np.where(pf['SALE'].isnull() ,0 , pf['SALE'])

# %%
#null값이 총 row의 10%를 넘어버리면 분석에 방해를 준다
#y축인 TOTAL_SELL 값의 null 값이 40000이 되므로 삭제한다.
pf = pf[pf.TOTAL_SELL !=0]

# %%
#타겟값으로 사용할 사이트 첫번째 페이지를 나타내는 칼럼 0과 1로 나눙 진다.
pf['FIRST_PAGE'] = 0

# %%
pf.head(80)
# Out:
#       index  POPULARITY  TOTAL_SELL  SATISFACTION  DELIVERY_DATE    PRICE  \
# 7         7    368097.0     71638.0          92.0            2.0  32760.0
# 265     265     76785.0     50364.0          94.0            2.0  27900.0
# 149     149    162376.0     44683.0          92.0            2.0  39200.0
# 1309   1309     14660.0     42763.0          91.0            2.0  50000.0
# 72       72    317868.0     38670.0          93.0            2.0  59000.0
# 46       46     88623.0     37405.0          98.0            2.0  69000.0
# 1029   1029     15590.0     35326.0          96.0            2.0  20900.0
# 4228   4228     39516.0     33756.0          93.0            2.0  55000.0
# 668     668     66146.0     33520.0          95.0            3.0  48000.0
# 248     248     20497.0     31803.0          98.0            2.0  59000.0
# 322     322    306069.0     28129.0          92.0            2.0  49900.0
# 761     761     67898.0     27614.0          90.0            3.0  26250.0
# ...

# %%
#First_page에 1을 선정하는 과정중 TOTAL_SELL을 1000개 단위로 나눠 중간값을 구함
total_sell_means = pd.DataFrame(data=[pf['TOTAL_SELL'][0:1000].mean(),pf['TOTAL_SELL'][1001:2000].mean(),pf['TOTAL_SELL'][2001:3000].mean(),pf['TOTAL_SELL'][3001:4000].mean(),pf['TOTAL_SELL'][4001:5000].mean(),pf['TOTAL_SELL'][5001:6000].mean(),pf['TOTAL_SELL'][6001:7000].mean(),pf['TOTAL_SELL'][7001:8000].mean(),pf['TOTAL_SELL'][8001:9000].mean(),pf['TOTAL_SELL'][9001:].mean()], index=range(0,10), columns=['means'])
display(pd.DataFrame(total_sell_means))
# Out:
#          means
# 0  3343.136000
# 1   168.537538
# 2    62.165165
# 3    34.163163
# 4    22.392392
# 5    16.308308
# 6    12.540541
# 7    10.357037
# 8          NaN
# 9          NaN

# %%
#TOTAL_SELL을 sort하고 시각화 한 결과 다음과 같은 그래프 확인
total_sell_means.plot()
plt.title("TOTAL_SELL_MEANS")
plt.xlabel("TOTAL_SELL")
plt.ylabel("MEANS")
plt.show()

# %%
pf = pf.sort_values(['POPULARITY'], ascending = False)
#인기도를 구간별로 나누기 위해 맥스 값과 민 값을 구한다
pf['POPULARITY'].max()
# Out:
# 812749.0

# %%
pf['POPULARITY'].min()
# Out:
# 22.0

# %%
#y값을 구별하기위한 칼럼이 인기도일때
POPULARITY_min = pd.DataFrame(data=[pf['POPULARITY'][0:1000].mean(),pf['POPULARITY'][1001:2000].mean(),pf['POPULARITY'][2001:3000].mean(),pf['POPULARITY'][3001:4000].mean(),pf['POPULARITY'][4001:5000].mean(),pf['POPULARITY'][5001:6000].mean(),pf['POPULARITY'][6001:7000].mean(),pf['POPULARITY'][7001:8000].mean(),pf['POPULARITY'][8001:9000].mean(),pf['POPULARITY'][9001:].mean()], index=range(0,10), columns=['means'])
display(pd.DataFrame(POPULARITY_min))
# Out:
#           means
# 0  34958.161000
# 1   4168.602603
# 2   1783.430430
# 3    903.747748
# 4    476.994995
# 5    267.021021
# 6    156.038038
# 7     84.065185
# 8           NaN
# 9           NaN

# %%
#랭킹 800위까지의 인기도범주에 따른 int값 추가
pf['POPULARITY'] = np.where(pf['POPULARITY'] <= 100, int('0'), pf['POPULARITY'])
pf['POPULARITY'] = np.where(pf['POPULARITY'] > 35000, int('7'), pf['POPULARITY'])
pf['POPULARITY'] = np.where(pf['POPULARITY'] > 4000, int('6'), pf['POPULARITY'])
pf['POPULARITY'] = np.where(pf['POPULARITY'] > 2000, int('5'), pf['POPULARITY'])
pf['POPULARITY'] = np.where(pf['POPULARITY'] > 1000, int('4'), pf['POPULARITY'])
pf['POPULARITY'] = np.where(pf['POPULARITY'] > 500, int('3'), pf['POPULARITY'])
pf['POPULARITY'] = np.where(pf['POPULARITY'] > 300, int('2'), pf['POPULARITY'])
pf['POPULARITY'] = np.where(pf['POPULARITY'] > 100, int('1'), pf['POPULARITY'])




pf
# Out:
#        index  POPULARITY  TOTAL_SELL  SATISFACTION  DELIVERY_DATE     PRICE  \
# 65        65         7.0     10983.0          92.0            4.0   99000.0
# 7          7         7.0     71638.0          92.0            2.0   32760.0
# 0          0         7.0     10000.0          94.0            2.0   31900.0
# 64        64         7.0     10000.0          95.0            2.0  125900.0
# 72        72         7.0     38670.0          93.0            2.0   59000.0
# 39        39         7.0      5853.0          93.0            4.0   99000.0
# 322      322         7.0     28129.0          92.0            2.0   49900.0
# 2          2         6.0     18525.0          94.0            2.0   86400.0
# 58        58         6.0      7465.0          95.0            4.0  199000.0
# 14        14         6.0     10000.0          94.0            2.0   31900.0
# 4230    4230         6.0      4609.0          96.0            2.0  246000.0
# ...

# %%
pf['TOTAL_SELL'].max()
# Out:
# 71638.0

# %%
pf['TOTAL_SELL'].min()
# Out:
# 10.0

# %%
TOTAL_SELL = pd.DataFrame(data=[pf['TOTAL_SELL'][0:1000].mean(),pf['TOTAL_SELL'][1001:2000].mean(),pf['TOTAL_SELL'][2001:3000].mean(),pf['TOTAL_SELL'][3001:4000].mean(),pf['TOTAL_SELL'][4001:5000].mean(),pf['TOTAL_SELL'][5001:6000].mean(),pf['TOTAL_SELL'][6001:7000].mean(),pf['TOTAL_SELL'][7001:8000].mean(),pf['TOTAL_SELL'][8001:9000].mean(),pf['TOTAL_SELL'][9001:].mean()], index=range(0,10), columns=['means'])
display(pd.DataFrame(TOTAL_SELL))
# Out:
#          means
# 0  2816.207000
# 1   471.770771
# 2   163.375375
# 3    82.828829
# 4    66.612613
# 5    30.921922
# 6    22.908909
# 7    18.411852
# 8          NaN
# 9          NaN

# %%
#랭킹 800위까지의 TOTAL_SELL범주에 따른 int값 추가
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] <= 10, int('0'), pf['TOTAL_SELL'])
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] > 2000, int('7'), pf['TOTAL_SELL'])
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] > 800, int('6'), pf['TOTAL_SELL'])
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] > 400, int('5'), pf['TOTAL_SELL'])
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] > 50, int('4'), pf['TOTAL_SELL'])
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] > 30, int('3'), pf['TOTAL_SELL'])
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] > 20, int('2'), pf['TOTAL_SELL'])
pf['TOTAL_SELL'] = np.where(pf['TOTAL_SELL'] > 10, int('1'), pf['TOTAL_SELL'])
pf
# Out:
#        index  POPULARITY  TOTAL_SELL  SATISFACTION  DELIVERY_DATE     PRICE  \
# 65        65         7.0         7.0          92.0            4.0   99000.0
# 7          7         7.0         7.0          92.0            2.0   32760.0
# 0          0         7.0         7.0          94.0            2.0   31900.0
# 64        64         7.0         7.0          95.0            2.0  125900.0
# 72        72         7.0         7.0          93.0            2.0   59000.0
# 39        39         7.0         7.0          93.0            4.0   99000.0
# 322      322         7.0         7.0          92.0            2.0   49900.0
# 2          2         6.0         7.0          94.0            2.0   86400.0
# 58        58         6.0         7.0          95.0            4.0  199000.0
# 14        14         6.0         7.0          94.0            2.0   31900.0
# 4230    4230         6.0         7.0          96.0            2.0  246000.0
# ...
