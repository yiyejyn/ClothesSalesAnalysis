# %% [markdown]
# # 무신사 데이터 분석 및 머신러닝 프로젝트

# %% [markdown]
# ###

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
  
plt.style.use('seaborn')
sns.set(font_scale=2.5)

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # 데이터 읽기

# %%
df_train = pd.read_csv("musinsa_final.csv")
#df_train = df_train.sort_values("TOTAL_SELL", ascending=False)
#title컬럼을 기준으로 중복 값 제거
df_train = df_train.drop_duplicates(['TITLE'])
df_train
# Out:
#        index                                              TITLE  \
# 0          0  테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]|TAPERED HIDDEN BANDING ...
# 1          1  12/26 배송 캐시미어20 오버핏 더블 롱 코트 (블랙)|캐시미어20 오버핏 더블...
# 2          2        Tydi crop jeans #0064|Tydi crop jeans #0064
# 3          3  삼성 블루투스 이어폰 갤럭시버즈 SM-R170|삼성 블루투스 이어폰 갤럭시버즈 SM...
# 4          4  공용 알래스카 에어 프리미엄 푸퍼 점퍼 _ PHZ4JP3220GR|공용 알래스카 에...
# ...      ...                                                ...
# 50122  50122  MD CHERRY COKE MTM(IVORY)|MD CHERRY COKE MTM(I...
# 50123  50123  패널 스웨트셔츠 - Grey/Black|Panel Sweatshirt - Grey/...
# 50124  50124  N193USW900 멀린 플리스 부클 후리스 빅로고 맨투맨 HAVANA KHAKI|...
# 50125  50125  TIEDYE CREWNECK IA [MINT]|TIEDYE CREWNECK IA [...
# 50126  50126  UNI RAW EDGE DETAIL SWEATSHIRTS (PWON3WSL37U0E...
#
#                      BRAND    SEASON  SEX  POPULARITY   BUCKET  TOTAL_SELL  \
# 0         MUSINSA STANDARD  2019ALL/    남    348380.0  28631.0     10000.0
# 1                     COOR  2019F/W/    남    170611.0   7235.0      3116.0
# 2                 FATALISM  2019F/W/    남    272331.0  16828.0     18525.0
# 3      SAMSUNG ELECTRONICS       NaN  라이프     74163.0   7716.0      3305.0
# 4                   POLHAM  2019F/W/    남    206928.0   6086.0      2286.0
# ...                    ...       ...  ...         ...      ...         ...
# 50122          LUV IS TRUE       NaN    여       532.0     42.0         NaN
# 50123             D.PRIQUE  2019F/W/    남       287.0     13.0         NaN
# 50124   NATIONALGEOGRAPHIC  2019F/W/    남      1188.0    108.0         NaN
# 50125           VIVASTUDIO  2019F/W/    남      1389.0    176.0        26.0
# 50126                 PLAC  2019F/W/    남        85.0     13.0         NaN
#
#          LIKE_  REVIEW  SATISFACTION  DELIVERY_DATE     PRICE  SALE  \
# 0      12150.0  8845.0          94.0            2.0   31900.0   NaN
# 1       3617.0  2441.0          95.0            2.0  256800.0  20.0
# 2      10969.0  8960.0          94.0            2.0   86400.0  10.0
# 3       1712.0   909.0          96.0            2.0  159500.0   NaN
# 4       3472.0   611.0          95.0            2.0  139000.0  30.0
# ...        ...     ...           ...            ...       ...   ...
# 50122     28.0     1.0         100.0            2.0   77000.0   NaN
# 50123     10.0     NaN         100.0            2.0   69300.0  30.0
# 50124     53.0    14.0         100.0            3.0   89000.0   NaN
# 50125    119.0    16.0          95.0            2.0   72000.0   NaN
# 50126     10.0     NaN          80.0            2.0   55200.0  20.0
#
#            CATEGORY_                                            IMG_URL
# 0          수트 팬츠/슬랙스  https://image.msscdn.net/images/goods_img/2019...
# 1           겨울 기타 코트  https://image.msscdn.net/images/goods_img/2017...
# 2              데님 팬츠  https://image.msscdn.net/images/goods_img/2017...
# 3                이어폰  https://image.msscdn.net/images/goods_img/2019...
# 4      숏 패딩/숏 헤비 아우터  https://image.msscdn.net/images/goods_img/2019...
# ...              ...                                                ...
# 50122      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50123      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50124      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50125      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50126      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
#
# [43311 rows x 16 columns]

# %%
df_train.describe()
# Out:
#               index     POPULARITY        BUCKET    TOTAL_SELL         LIKE_  \
# count  43311.000000   43310.000000  42362.000000   7676.000000  37462.000000
# mean   26115.588349    1399.053198    150.671569    477.658155    110.562036
# std    14261.416959   10468.865875   1060.262019   2354.779404    703.722698
# min        0.000000       6.000000      0.000000     10.000000      1.000000
# 25%    13954.500000      49.000000      3.000000     15.000000      3.000000
# 50%    26526.000000      95.000000     10.000000     29.000000     10.000000
# 75%    38433.500000     295.000000     37.000000     96.000000     32.000000
# max    50126.000000  812749.000000  44356.000000  71638.000000  25964.000000
#
#              REVIEW  SATISFACTION  DELIVERY_DATE         PRICE          SALE
# count  15600.000000  43310.000000   42917.000000  4.331000e+04  23612.000000
# mean     370.021026     90.371277       1.962206  1.283339e+05     33.723827
# std     2247.306914     13.323649       0.747174  1.841422e+05     15.502748
# min        0.000000     20.000000       0.000000  5.000000e+03      3.000000
# 25%        2.000000     80.000000       2.000000  4.550000e+04     20.000000
# 50%        6.000000     95.000000       2.000000  7.200000e+04     30.000000
# 75%       27.000000    100.000000       2.000000  1.399000e+05     43.000000
# max    43588.000000    100.000000      14.000000  5.391000e+06     90.000000

# %%
#널 값의 비율을 알아본다
df_train.isnull().sum()/len(df_train)
# Out:
# index            0.000000
# TITLE            0.000023
# BRAND            0.000023
# SEASON           0.398259
# SEX              0.000023
# POPULARITY       0.000023
# BUCKET           0.021911
# TOTAL_SELL       0.822770
# LIKE_            0.135047
# REVIEW           0.639814
# SATISFACTION     0.000023
# DELIVERY_DATE    0.009097
# PRICE            0.000023
# SALE             0.454827
# CATEGORY_        0.000023
# IMG_URL          0.000023
# dtype: float64

# %%
import missingno as msno
msno.bar(df=df_train)

# %%
#SALE의 null값은 할인률이 없는, 즉 할인하지 않는다는 의미이므로 0%로 바꿔준다
df_train['SALE'] = np.where(df_train['SALE'].isnull() ,0 , df_train['SALE'])
df_train
# Out:
#        index                                              TITLE  \
# 0          0  테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]|TAPERED HIDDEN BANDING ...
# 1          1  12/26 배송 캐시미어20 오버핏 더블 롱 코트 (블랙)|캐시미어20 오버핏 더블...
# 2          2        Tydi crop jeans #0064|Tydi crop jeans #0064
# 3          3  삼성 블루투스 이어폰 갤럭시버즈 SM-R170|삼성 블루투스 이어폰 갤럭시버즈 SM...
# 4          4  공용 알래스카 에어 프리미엄 푸퍼 점퍼 _ PHZ4JP3220GR|공용 알래스카 에...
# ...      ...                                                ...
# 50122  50122  MD CHERRY COKE MTM(IVORY)|MD CHERRY COKE MTM(I...
# 50123  50123  패널 스웨트셔츠 - Grey/Black|Panel Sweatshirt - Grey/...
# 50124  50124  N193USW900 멀린 플리스 부클 후리스 빅로고 맨투맨 HAVANA KHAKI|...
# 50125  50125  TIEDYE CREWNECK IA [MINT]|TIEDYE CREWNECK IA [...
# 50126  50126  UNI RAW EDGE DETAIL SWEATSHIRTS (PWON3WSL37U0E...
#
#                      BRAND    SEASON  SEX  POPULARITY   BUCKET  TOTAL_SELL  \
# 0         MUSINSA STANDARD  2019ALL/    남    348380.0  28631.0     10000.0
# 1                     COOR  2019F/W/    남    170611.0   7235.0      3116.0
# 2                 FATALISM  2019F/W/    남    272331.0  16828.0     18525.0
# 3      SAMSUNG ELECTRONICS       NaN  라이프     74163.0   7716.0      3305.0
# 4                   POLHAM  2019F/W/    남    206928.0   6086.0      2286.0
# ...                    ...       ...  ...         ...      ...         ...
# 50122          LUV IS TRUE       NaN    여       532.0     42.0         NaN
# 50123             D.PRIQUE  2019F/W/    남       287.0     13.0         NaN
# 50124   NATIONALGEOGRAPHIC  2019F/W/    남      1188.0    108.0         NaN
# 50125           VIVASTUDIO  2019F/W/    남      1389.0    176.0        26.0
# 50126                 PLAC  2019F/W/    남        85.0     13.0         NaN
#
#          LIKE_  REVIEW  SATISFACTION  DELIVERY_DATE     PRICE  SALE  \
# 0      12150.0  8845.0          94.0            2.0   31900.0   0.0
# 1       3617.0  2441.0          95.0            2.0  256800.0  20.0
# 2      10969.0  8960.0          94.0            2.0   86400.0  10.0
# 3       1712.0   909.0          96.0            2.0  159500.0   0.0
# 4       3472.0   611.0          95.0            2.0  139000.0  30.0
# ...        ...     ...           ...            ...       ...   ...
# 50122     28.0     1.0         100.0            2.0   77000.0   0.0
# 50123     10.0     NaN         100.0            2.0   69300.0  30.0
# 50124     53.0    14.0         100.0            3.0   89000.0   0.0
# 50125    119.0    16.0          95.0            2.0   72000.0   0.0
# 50126     10.0     NaN          80.0            2.0   55200.0  20.0
#
#            CATEGORY_                                            IMG_URL
# 0          수트 팬츠/슬랙스  https://image.msscdn.net/images/goods_img/2019...
# 1           겨울 기타 코트  https://image.msscdn.net/images/goods_img/2017...
# 2              데님 팬츠  https://image.msscdn.net/images/goods_img/2017...
# 3                이어폰  https://image.msscdn.net/images/goods_img/2019...
# 4      숏 패딩/숏 헤비 아우터  https://image.msscdn.net/images/goods_img/2019...
# ...              ...                                                ...
# 50122      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50123      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50124      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50125      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50126      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
#
# [43311 rows x 16 columns]

# %%
#LIKE의 null값은 좋아요를 1개도 받지 못했다는 의미이므로 0개로 바꿔준다
df_train['LIKE_'] = np.where(df_train['LIKE_'].isnull() ,0 , df_train['LIKE_'])
df_train
# Out:
#        index                                              TITLE  \
# 0          0  테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]|TAPERED HIDDEN BANDING ...
# 1          1  12/26 배송 캐시미어20 오버핏 더블 롱 코트 (블랙)|캐시미어20 오버핏 더블...
# 2          2        Tydi crop jeans #0064|Tydi crop jeans #0064
# 3          3  삼성 블루투스 이어폰 갤럭시버즈 SM-R170|삼성 블루투스 이어폰 갤럭시버즈 SM...
# 4          4  공용 알래스카 에어 프리미엄 푸퍼 점퍼 _ PHZ4JP3220GR|공용 알래스카 에...
# ...      ...                                                ...
# 50122  50122  MD CHERRY COKE MTM(IVORY)|MD CHERRY COKE MTM(I...
# 50123  50123  패널 스웨트셔츠 - Grey/Black|Panel Sweatshirt - Grey/...
# 50124  50124  N193USW900 멀린 플리스 부클 후리스 빅로고 맨투맨 HAVANA KHAKI|...
# 50125  50125  TIEDYE CREWNECK IA [MINT]|TIEDYE CREWNECK IA [...
# 50126  50126  UNI RAW EDGE DETAIL SWEATSHIRTS (PWON3WSL37U0E...
#
#                      BRAND    SEASON  SEX  POPULARITY   BUCKET  TOTAL_SELL  \
# 0         MUSINSA STANDARD  2019ALL/    남    348380.0  28631.0     10000.0
# 1                     COOR  2019F/W/    남    170611.0   7235.0      3116.0
# 2                 FATALISM  2019F/W/    남    272331.0  16828.0     18525.0
# 3      SAMSUNG ELECTRONICS       NaN  라이프     74163.0   7716.0      3305.0
# 4                   POLHAM  2019F/W/    남    206928.0   6086.0      2286.0
# ...                    ...       ...  ...         ...      ...         ...
# 50122          LUV IS TRUE       NaN    여       532.0     42.0         NaN
# 50123             D.PRIQUE  2019F/W/    남       287.0     13.0         NaN
# 50124   NATIONALGEOGRAPHIC  2019F/W/    남      1188.0    108.0         NaN
# 50125           VIVASTUDIO  2019F/W/    남      1389.0    176.0        26.0
# 50126                 PLAC  2019F/W/    남        85.0     13.0         NaN
#
#          LIKE_  REVIEW  SATISFACTION  DELIVERY_DATE     PRICE  SALE  \
# 0      12150.0  8845.0          94.0            2.0   31900.0   0.0
# 1       3617.0  2441.0          95.0            2.0  256800.0  20.0
# 2      10969.0  8960.0          94.0            2.0   86400.0  10.0
# 3       1712.0   909.0          96.0            2.0  159500.0   0.0
# 4       3472.0   611.0          95.0            2.0  139000.0  30.0
# ...        ...     ...           ...            ...       ...   ...
# 50122     28.0     1.0         100.0            2.0   77000.0   0.0
# 50123     10.0     NaN         100.0            2.0   69300.0  30.0
# 50124     53.0    14.0         100.0            3.0   89000.0   0.0
# 50125    119.0    16.0          95.0            2.0   72000.0   0.0
# 50126     10.0     NaN          80.0            2.0   55200.0  20.0
#
#            CATEGORY_                                            IMG_URL
# 0          수트 팬츠/슬랙스  https://image.msscdn.net/images/goods_img/2019...
# 1           겨울 기타 코트  https://image.msscdn.net/images/goods_img/2017...
# 2              데님 팬츠  https://image.msscdn.net/images/goods_img/2017...
# 3                이어폰  https://image.msscdn.net/images/goods_img/2019...
# 4      숏 패딩/숏 헤비 아우터  https://image.msscdn.net/images/goods_img/2019...
# ...              ...                                                ...
# 50122      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50123      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50124      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50125      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
# 50126      맨투맨/스웨트셔츠  https://image.msscdn.net/images/goods_img/2019...
#
# [43311 rows x 16 columns]

# %%
# season, review 항목은 사용하지 않기로 한다.
df_train = df_train.drop(['SEASON' , 'REVIEW'] , axis=1)
df_train
# Out:
#        index                                              TITLE  \
# 0          0  테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]|TAPERED HIDDEN BANDING ...
# 1          1  12/26 배송 캐시미어20 오버핏 더블 롱 코트 (블랙)|캐시미어20 오버핏 더블...
# 2          2        Tydi crop jeans #0064|Tydi crop jeans #0064
# 3          3  삼성 블루투스 이어폰 갤럭시버즈 SM-R170|삼성 블루투스 이어폰 갤럭시버즈 SM...
# 4          4  공용 알래스카 에어 프리미엄 푸퍼 점퍼 _ PHZ4JP3220GR|공용 알래스카 에...
# ...      ...                                                ...
# 50122  50122  MD CHERRY COKE MTM(IVORY)|MD CHERRY COKE MTM(I...
# 50123  50123  패널 스웨트셔츠 - Grey/Black|Panel Sweatshirt - Grey/...
# 50124  50124  N193USW900 멀린 플리스 부클 후리스 빅로고 맨투맨 HAVANA KHAKI|...
# 50125  50125  TIEDYE CREWNECK IA [MINT]|TIEDYE CREWNECK IA [...
# 50126  50126  UNI RAW EDGE DETAIL SWEATSHIRTS (PWON3WSL37U0E...
#
#                      BRAND  SEX  POPULARITY   BUCKET  TOTAL_SELL    LIKE_  \
# 0         MUSINSA STANDARD    남    348380.0  28631.0     10000.0  12150.0
# 1                     COOR    남    170611.0   7235.0      3116.0   3617.0
# 2                 FATALISM    남    272331.0  16828.0     18525.0  10969.0
# 3      SAMSUNG ELECTRONICS  라이프     74163.0   7716.0      3305.0   1712.0
# 4                   POLHAM    남    206928.0   6086.0      2286.0   3472.0
# ...                    ...  ...         ...      ...         ...      ...
# 50122          LUV IS TRUE    여       532.0     42.0         NaN     28.0
# 50123             D.PRIQUE    남       287.0     13.0         NaN     10.0
# 50124   NATIONALGEOGRAPHIC    남      1188.0    108.0         NaN     53.0
# 50125           VIVASTUDIO    남      1389.0    176.0        26.0    119.0
# 50126                 PLAC    남        85.0     13.0         NaN     10.0
#
#        SATISFACTION  DELIVERY_DATE     PRICE  SALE      CATEGORY_  \
# 0              94.0            2.0   31900.0   0.0      수트 팬츠/슬랙스
# 1              95.0            2.0  256800.0  20.0       겨울 기타 코트
# 2              94.0            2.0   86400.0  10.0          데님 팬츠
# 3              96.0            2.0  159500.0   0.0            이어폰
# 4              95.0            2.0  139000.0  30.0  숏 패딩/숏 헤비 아우터
# ...             ...            ...       ...   ...            ...
# 50122         100.0            2.0   77000.0   0.0      맨투맨/스웨트셔츠
# 50123         100.0            2.0   69300.0  30.0      맨투맨/스웨트셔츠
# 50124         100.0            3.0   89000.0   0.0      맨투맨/스웨트셔츠
# 50125          95.0            2.0   72000.0   0.0      맨투맨/스웨트셔츠
# 50126          80.0            2.0   55200.0  20.0      맨투맨/스웨트셔츠
#
#                                                  IMG_URL
# 0      https://image.msscdn.net/images/goods_img/2019...
# 1      https://image.msscdn.net/images/goods_img/2017...
# 2      https://image.msscdn.net/images/goods_img/2017...
# 3      https://image.msscdn.net/images/goods_img/2019...
# 4      https://image.msscdn.net/images/goods_img/2019...
# ...                                                  ...
# 50122  https://image.msscdn.net/images/goods_img/2019...
# 50123  https://image.msscdn.net/images/goods_img/2019...
# 50124  https://image.msscdn.net/images/goods_img/2019...
# 50125  https://image.msscdn.net/images/goods_img/2019...
# 50126  https://image.msscdn.net/images/goods_img/2019...
#
# [43311 rows x 14 columns]

# %%
#null값이 총 row의 10%를 넘어버리면 분석에 방해를 준다
#y축인 TOTAL_SELL 값의 null 값이 40000이 되므로 삭제한다.
df_train = df_train.dropna()
df_train
# Out:
#        index                                              TITLE  \
# 0          0  테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]|TAPERED HIDDEN BANDING ...
# 1          1  12/26 배송 캐시미어20 오버핏 더블 롱 코트 (블랙)|캐시미어20 오버핏 더블...
# 2          2        Tydi crop jeans #0064|Tydi crop jeans #0064
# 3          3  삼성 블루투스 이어폰 갤럭시버즈 SM-R170|삼성 블루투스 이어폰 갤럭시버즈 SM...
# 4          4  공용 알래스카 에어 프리미엄 푸퍼 점퍼 _ PHZ4JP3220GR|공용 알래스카 에...
# ...      ...                                                ...
# 50107  50107    스마일 로고 스웨트셔츠 (브라운)|SMILE LOGO SWEATSHIRTS BROWN
# 50108  50108  GNAC POCKET SWEATSHIRT_OATMEAL|GNAC POCKET SWE...
# 50114  50114  [NK] PROGRESSIVE SWEATSHIRTS (PURPLE) (19FW-K0...
# 50117  50117  [기모][K.N.I.T]밀리터리 아플리케 스웨트 셔츠 카키|[기모][K.N.I.T]...
# 50125  50125  TIEDYE CREWNECK IA [MINT]|TIEDYE CREWNECK IA [...
#
#                      BRAND  SEX  POPULARITY   BUCKET  TOTAL_SELL    LIKE_  \
# 0         MUSINSA STANDARD    남    348380.0  28631.0     10000.0  12150.0
# 1                     COOR    남    170611.0   7235.0      3116.0   3617.0
# 2                 FATALISM    남    272331.0  16828.0     18525.0  10969.0
# 3      SAMSUNG ELECTRONICS  라이프     74163.0   7716.0      3305.0   1712.0
# 4                   POLHAM    남    206928.0   6086.0      2286.0   3472.0
# ...                    ...  ...         ...      ...         ...      ...
# 50107                 COVE    여       461.0     50.0        12.0     35.0
# 50108       ROMANTIC CROWN    여      1011.0    118.0        12.0     87.0
# 50114            NASTYKICK    남       978.0    198.0        56.0    151.0
# 50117        BEYOND CLOSET    남       364.0     99.0        12.0     64.0
# 50125           VIVASTUDIO    남      1389.0    176.0        26.0    119.0
#
#        SATISFACTION  DELIVERY_DATE     PRICE  SALE      CATEGORY_  \
# 0              94.0            2.0   31900.0   0.0      수트 팬츠/슬랙스
# 1              95.0            2.0  256800.0  20.0       겨울 기타 코트
# 2              94.0            2.0   86400.0  10.0          데님 팬츠
# 3              96.0            2.0  159500.0   0.0            이어폰
# 4              95.0            2.0  139000.0  30.0  숏 패딩/숏 헤비 아우터
# ...             ...            ...       ...   ...            ...
# 50107          80.0            4.0   30800.0  30.0      맨투맨/스웨트셔츠
# 50108         100.0            2.0   44000.0  20.0      맨투맨/스웨트셔츠
# 50114          92.0            2.0   31200.0  40.0      맨투맨/스웨트셔츠
# 50117          90.0            2.0   60000.0  20.0      맨투맨/스웨트셔츠
# 50125          95.0            2.0   72000.0   0.0      맨투맨/스웨트셔츠
#
#                                                  IMG_URL
# 0      https://image.msscdn.net/images/goods_img/2019...
# 1      https://image.msscdn.net/images/goods_img/2017...
# 2      https://image.msscdn.net/images/goods_img/2017...
# 3      https://image.msscdn.net/images/goods_img/2019...
# 4      https://image.msscdn.net/images/goods_img/2019...
# ...                                                  ...
# 50107  https://image.msscdn.net/images/goods_img/2019...
# 50108  https://image.msscdn.net/images/goods_img/2019...
# 50114  https://image.msscdn.net/images/goods_img/2019...
# 50117  https://image.msscdn.net/images/goods_img/2019...
# 50125  https://image.msscdn.net/images/goods_img/2019...
#
# [7664 rows x 14 columns]

# %% [markdown]
# # 타겟값 분류

# %% [markdown]
# > 랭킹 페이지에서 10페이지 이하에 들어갈수록 상품의 판매량이 좋아질 것으로 예상한다. 따라서, 중복 값 제거 후의 인덱스 값(랭킹 순위)에 따라 800 이하일 경우를 1로, 이상일 경우를 0으로 놓는다.

# %%
# 상위 페이지를 나타내는 칼럼 'first_page' 생성, 0과 1로 나누어진다.
df_train['FIRST_PAGE'] = 0
df_train.head()
# Out:
#    index                                              TITLE  \
# 0      0  테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]|TAPERED HIDDEN BANDING ...
# 1      1  12/26 배송 캐시미어20 오버핏 더블 롱 코트 (블랙)|캐시미어20 오버핏 더블...
# 2      2        Tydi crop jeans #0064|Tydi crop jeans #0064
# 3      3  삼성 블루투스 이어폰 갤럭시버즈 SM-R170|삼성 블루투스 이어폰 갤럭시버즈 SM...
# 4      4  공용 알래스카 에어 프리미엄 푸퍼 점퍼 _ PHZ4JP3220GR|공용 알래스카 에...
#
#                  BRAND  SEX  POPULARITY   BUCKET  TOTAL_SELL    LIKE_  \
# 0     MUSINSA STANDARD    남    348380.0  28631.0     10000.0  12150.0
# 1                 COOR    남    170611.0   7235.0      3116.0   3617.0
# 2             FATALISM    남    272331.0  16828.0     18525.0  10969.0
# 3  SAMSUNG ELECTRONICS  라이프     74163.0   7716.0      3305.0   1712.0
# 4               POLHAM    남    206928.0   6086.0      2286.0   3472.0
#
#    SATISFACTION  DELIVERY_DATE     PRICE  SALE      CATEGORY_  \
# 0          94.0            2.0   31900.0   0.0      수트 팬츠/슬랙스
# 1          95.0            2.0  256800.0  20.0       겨울 기타 코트
# 2          94.0            2.0   86400.0  10.0          데님 팬츠
# 3          96.0            2.0  159500.0   0.0            이어폰
# 4          95.0            2.0  139000.0  30.0  숏 패딩/숏 헤비 아우터
#
#                                              IMG_URL  FIRST_PAGE
# 0  https://image.msscdn.net/images/goods_img/2019...           0
# 1  https://image.msscdn.net/images/goods_img/2017...           0
# 2  https://image.msscdn.net/images/goods_img/2017...           0
# 3  https://image.msscdn.net/images/goods_img/2019...           0
# 4  https://image.msscdn.net/images/goods_img/2019...           0

# %%
# 1 페이지는 80개의 상품을 가지고 있기 때문에 상위 800개만 10페이지에 들어가게 된다.
df_train['FIRST_PAGE'][0:800] = 1
df_train.head()
# Out:
#    index                                              TITLE  \
# 0      0  테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]|TAPERED HIDDEN BANDING ...
# 1      1  12/26 배송 캐시미어20 오버핏 더블 롱 코트 (블랙)|캐시미어20 오버핏 더블...
# 2      2        Tydi crop jeans #0064|Tydi crop jeans #0064
# 3      3  삼성 블루투스 이어폰 갤럭시버즈 SM-R170|삼성 블루투스 이어폰 갤럭시버즈 SM...
# 4      4  공용 알래스카 에어 프리미엄 푸퍼 점퍼 _ PHZ4JP3220GR|공용 알래스카 에...
#
#                  BRAND  SEX  POPULARITY   BUCKET  TOTAL_SELL    LIKE_  \
# 0     MUSINSA STANDARD    남    348380.0  28631.0     10000.0  12150.0
# 1                 COOR    남    170611.0   7235.0      3116.0   3617.0
# 2             FATALISM    남    272331.0  16828.0     18525.0  10969.0
# 3  SAMSUNG ELECTRONICS  라이프     74163.0   7716.0      3305.0   1712.0
# 4               POLHAM    남    206928.0   6086.0      2286.0   3472.0
#
#    SATISFACTION  DELIVERY_DATE     PRICE  SALE      CATEGORY_  \
# 0          94.0            2.0   31900.0   0.0      수트 팬츠/슬랙스
# 1          95.0            2.0  256800.0  20.0       겨울 기타 코트
# 2          94.0            2.0   86400.0  10.0          데님 팬츠
# 3          96.0            2.0  159500.0   0.0            이어폰
# 4          95.0            2.0  139000.0  30.0  숏 패딩/숏 헤비 아우터
#
#                                              IMG_URL  FIRST_PAGE
# 0  https://image.msscdn.net/images/goods_img/2019...           1
# 1  https://image.msscdn.net/images/goods_img/2017...           1
# 2  https://image.msscdn.net/images/goods_img/2017...           1
# 3  https://image.msscdn.net/images/goods_img/2019...           1
# 4  https://image.msscdn.net/images/goods_img/2019...           1

# %%
df_train['FIRST_PAGE'].value_counts()
# Out:
# 0    6864
# 1     800
# Name: FIRST_PAGE, dtype: int64

# %%
total_sell_means = pd.DataFrame(data=[df_train['TOTAL_SELL'][0:1000].mean(),df_train['TOTAL_SELL'][1001:2000].mean(),df_train['TOTAL_SELL'][2001:3000].mean(),df_train['TOTAL_SELL'][3001:4000].mean(),df_train['TOTAL_SELL'][4001:5000].mean(),df_train['TOTAL_SELL'][5001:6000].mean(),df_train['TOTAL_SELL'][6001:7000].mean(),df_train['TOTAL_SELL'][7001:].mean()], index=range(0,8), columns=['means'])
display(pd.DataFrame(total_sell_means))
# Out:
#          means
# 0  2299.076000
# 1   834.423423
# 2   391.557558
# 3    42.561562
# 4    24.656657
# 5    31.031031
# 6    26.956957
# 7    23.449472

# %% [markdown]
# # 상관관계 분석

# %%
#First_page에 1을 선정하는 과정중 TOTAL_SELL을 1000개 단위로 나눠 중간값을 구함
total_sell_means = pd.DataFrame(data=[pf['TOTAL_SELL'][0:1000].mean(),pf['TOTAL_SELL'][1001:2000].mean(),pf['TOTAL_SELL'][2001:3000].mean(),pf['TOTAL_SELL'][3001:4000].mean(),pf['TOTAL_SELL'][4001:5000].mean(),pf['TOTAL_SELL'][5001:6000].mean(),pf['TOTAL_SELL'][6001:7000].mean(),pf['TOTAL_SELL'][7001:8000].mean(),pf['TOTAL_SELL'][8001:9000].mean(),pf['TOTAL_SELL'][9001:].mean()], index=range(0,10), columns=['means'])
display(pd.DataFrame(total_sell_means))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0a7c4542b5dd> in <module>
#       1 #First_page에 1을 선정하는 과정중 TOTAL_SELL을 1000개 단위로 나눠 중간값을 구함
# ----> 2 total_sell_means = pd.DataFrame(data=[pf['TOTAL_SELL'][0:1000].mean(),pf['TOTAL_SELL'][1001:2000].mean(),pf['TOTAL_SELL'][2001:3000].mean(),pf['TOTAL_SELL'][3001:4000].mean(),pf['TOTAL_SELL'][4001:5000].mean(),pf['TOTAL_SELL'][5001:6000].mean(),pf['TOTAL_SELL'][6001:7000].mean(),pf['TOTAL_SELL'][7001:8000].mean(),pf['TOTAL_SELL'][8001:9000].mean(),pf['TOTAL_SELL'][9001:].mean()], index=range(0,10), columns=['means'])
#       3 display(pd.DataFrame(total_sell_means))
#
# NameError: name 'pf' is not defined

# %%
total_sell_means.plot()
plt.title("TOTAL_SELL_MEANS")
plt.xlabel("TOTAL_SELL")
plt.ylabel("MEANS")
plt.show()
